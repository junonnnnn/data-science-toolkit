# %% [markdown]
# <a href="https://colab.research.google.com/github/junonnnnn/data-science-toolkit/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Data Science")
# Out:
# Welcome to Data Science

# %%
x = 5
print("Value of x is: ", x)
print(type(x))
# Out:
# Value of x is:  5
# <class 'int'>

# %%
y = "I am Yong Jun Onn"
print(y)
# Out:
# I am Yong Jun Onn

# %%
a = []
a.append(y)
a[0][1]
# Out:
# ' '

# %%
b = str.split(y)
b[4]
# Out:
# 'Onn'

# %%
import numpy as np
a = []
for i in range(1, 11):
    a.append(i)
b = np.array(a)
b[3]
# Out:
# np.int64(4)

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
print(f"Hi, {y}")
# Out:
# Hi, I am Yong Jun Onn

# %%
alt = '{}'.format(y)
print(alt)
# Out:
# I am Yong Jun Onn

# %%
num1 = a[2]

print(f"The 3rd number in list a is {str(a[2])}")
# Out:
# The 3rd number in list a is 3

# %%
list1 = [1, 2, 3, 4, 5]
list1.pop()
print(list1)
# Out:
# [1, 2, 3, 4]

# %%
numbers = list(range(6))
print(numbers)
print(numbers[2:])
numbers[2:4] = [10, 20]
print(numbers)
# Out:
# [0, 1, 2, 3, 4, 5]
# [2, 3, 4, 5]
# [0, 1, 10, 20, 4, 5]

# %%
dict = {'cat': 'cute', 'dog': 'furry'}
print(dict['cat'])
print('cat' in dict)
# Out:
# cute
# True

# %%
array1 = np.array([1, 2, 3])
print(type(array1), array1.shape)
array2 = np.array([4, 5, 6])
stack1 = np.stack((array1, array2))
print(stack1, stack1.shape)
# Out:
# <class 'numpy.ndarray'> (3,)
# [[1 2 3]
#  [4 5 6]] (2, 3)

# %%
stack2 = np.stack((array1, array2), axis=0)
print(stack2, stack2.shape)
#alternative
print(stack2[1,2])
# Out:
# [[1 2 3]
#  [4 5 6]] (2, 3)
# 6

# %%
n1 = np.ones((1,2))
n1
# Out:
# array([[1., 1.]])

# %%
n2 = np.ones((2,2))
n2
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
n3 = np.full((2,2), 7)
n3
# Out:
# array([[7, 7],
#        [7, 7]])

# %%
n4 = np.eye(3)
n4
# Identity Matrices
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
n5 = np.random.random((2,2))
n5
# Out:
# array([[0.99678394, 0.39760297],
#        [0.14938748, 0.72958391]])

# %%
print(n5[1, :])
# Out:
# [0.14938748 0.72958391]
